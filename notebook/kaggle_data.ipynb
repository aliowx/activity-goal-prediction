# %%
import pandas as pd

# %%
df = pd.read_csv('../fast_food_ordering_dataset.csv')

# %%
df.head()
# Out:
#     order_id           order_time       city cuisine_type  order_value  \
# 0  ORD100000  2025-10-05 21:16:00       Pune      Healthy       867.98
# 1  ORD100001  2025-06-07 09:40:00  Hyderabad    Fast Food       689.71
# 2  ORD100002  2025-12-20 18:46:00    Chennai    Fast Food       440.48
# 3  ORD100003  2025-06-07 14:10:00       Pune      Mexican       995.17
# 4  ORD100004  2025-05-11 00:48:00  Bengaluru      Healthy       853.20
#
#    delivery_time_minutes payment_method  items_count
# 0                     61            UPI            3
# 1                     26         Wallet            3
# 2                     30    Credit Card            4
# 3                     38    Credit Card            6
# 4                     33     Debit Card            7

# %%
df.isnull().sum()
# Out:
# order_id                 0
# order_time               0
# city                     0
# cuisine_type             0
# order_value              0
# delivery_time_minutes    0
# payment_method           0
# items_count              0
# dtype: int64

# %%
df.city.value_counts()
# Out:
# city
# Hyderabad    76
# Ahmedabad    72
# Mumbai       71
# Bengaluru    64
# Kolkata      62
# Pune         58
# Chennai      51
# Delhi        46
# Name: count, dtype: int64

# %%
wild_lands = df.loc[df.city.isin(['Hyderabad', 'Ahmedabad'])].copy()
wild_lands.head()
# Out:
#      order_id           order_time       city  cuisine_type  order_value  \
# 1   ORD100001  2025-06-07 09:40:00  Hyderabad     Fast Food       689.71
# 5   ORD100005  2025-01-02 05:07:00  Ahmedabad  North Indian       278.88
# 14  ORD100014  2025-06-09 07:08:00  Ahmedabad  South Indian       149.74
# 16  ORD100016  2025-11-30 12:51:00  Hyderabad       Mexican       514.11
# 17  ORD100017  2025-03-22 17:48:00  Ahmedabad        Bakery       991.61
#
#     delivery_time_minutes payment_method  items_count
# 1                      26         Wallet            3
# 5                      22         Wallet            2
# 14                     22           Cash            6
# 16                     32           Cash            5
# 17                     39           Cash            4

# %%
wild_lands.plot()
# Out:
# <Axes: >

# %%
regions = gpd.read_file("../ne_110m_admin_0_countries.shp")
print(regions.crs)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
